# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatrohithk/coursera-test/blob/main/21BDS0184_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Kodumuri Venkat Rohith**
#
# **21BDS0184**
#
# Github link: https://github.com/venkatrohithk/coursera-test/blob/main/21BDS0184_EDA.ipynb

# %%
#21BDS0184
import pandas as pd
import numpy as np

# %%
#21BDS0184
df = pd.read_csv("Fertility2.csv")
df.head()
# Out:
#    rownames morekids gender1 gender2   age afam hispanic other  work
# 0         1       no  female  female  35.0   no       no    no    40
# 1         2       no  female    male  33.0   no       no    no    52
# 2         3       no  female  female  28.0   no       no    no    12
# 3         4       no    male    male  28.0   no       no    no     0
# 4         5       no  female    male  31.0   no       no    no     0

# %%
#21BDS0184
df.describe()
# Out:
#            rownames           age          work
# count  30007.000000  30006.000000  30007.000000
# mean   15001.482221     30.354429     19.206352
# std     8661.760763      3.383235     21.939757
# min        1.000000     21.000000      0.000000
# 25%     7500.500000     28.000000      0.000000
# 50%    15001.000000     31.000000      6.000000
# 75%    22502.500000     33.000000     45.000000
# max    30000.000000     35.000000     52.000000

# %%
df.shape
# Out:
# (30007, 9)

# %%
df.isna().sum()
# Out:
# rownames    0
# morekids    0
# gender1     0
# gender2     0
# age         1
# afam        0
# hispanic    1
# other       0
# work        0
# dtype: int64

# %%
df.stack()
# Out:
# 0      rownames         1
#        morekids        no
#        gender1     female
#        gender2     female
#        age           35.0
#                     ...
# 30006  age           31.0
#        afam            no
#        hispanic        no
#        other           no
#        work             0
# Length: 270061, dtype: object

# %%
df.unstack()
# Out:
# rownames  0         1
#           1         2
#           2         3
#           3         4
#           4         5
#                    ..
# work      30002    22
#           30003    12
#           30004     0
#           30005     0
#           30006     0
# Length: 270063, dtype: object

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 30002    False
# 30003     True
# 30004     True
# 30005     True
# 30006     True
# Length: 30007, dtype: bool

# %%
df1 = df.drop_duplicates()
df1
# Out:
#        rownames morekids gender1 gender2   age afam hispanic other  work
# 0             1       no  female  female  35.0   no       no    no    40
# 1             2       no  female    male  33.0   no       no    no    52
# 2             3       no  female  female  28.0   no       no    no    12
# 3             4       no    male    male  28.0   no       no    no     0
# 4             5       no  female    male  31.0   no       no    no     0
# ...         ...      ...     ...     ...   ...  ...      ...   ...   ...
# 29997     29998      yes    male  female  34.0   no       no    no    42
# 29998     29999      yes    male    male  31.0  yes       no    no    52
# 29999     30000       no  female  female  29.0   no       no    no     0
# 30001     29721       no    male    male   NaN   no       no    no     6
# 30002      5577       no    male  female  33.0   no      NaN    no    22
#
# [30002 rows x 9 columns]

# %%
df1.notnull()
# Out:
#        rownames  morekids  gender1  gender2    age  afam  hispanic  other  \
# 0          True      True     True     True   True  True      True   True
# 1          True      True     True     True   True  True      True   True
# 2          True      True     True     True   True  True      True   True
# 3          True      True     True     True   True  True      True   True
# 4          True      True     True     True   True  True      True   True
# ...         ...       ...      ...      ...    ...   ...       ...    ...
# 29997      True      True     True     True   True  True      True   True
# 29998      True      True     True     True   True  True      True   True
# 29999      True      True     True     True   True  True      True   True
# 30001      True      True     True     True  False  True      True   True
# 30002      True      True     True     True   True  True     False   True
#
#        work
# 0      True
# 1      True
# 2      True
# 3      True
# ...

# %%
df1.isnull()
# Out:
#        rownames  morekids  gender1  gender2    age   afam  hispanic  other  \
# 0         False     False    False    False  False  False     False  False
# 1         False     False    False    False  False  False     False  False
# 2         False     False    False    False  False  False     False  False
# 3         False     False    False    False  False  False     False  False
# 4         False     False    False    False  False  False     False  False
# ...         ...       ...      ...      ...    ...    ...       ...    ...
# 29997     False     False    False    False  False  False     False  False
# 29998     False     False    False    False  False  False     False  False
# 29999     False     False    False    False  False  False     False  False
# 30001     False     False    False    False   True  False     False  False
# 30002     False     False    False    False  False  False      True  False
#
#         work
# 0      False
# 1      False
# 2      False
# ...

# %%
df1.isnull().sum()
# Out:
# rownames    0
# morekids    0
# gender1     0
# gender2     0
# age         1
# afam        0
# hispanic    1
# other       0
# work        0
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 2

# %%
df1.count()
# Out:
# rownames    30002
# morekids    30002
# gender1     30002
# gender2     30002
# age         30001
# afam        30002
# hispanic    30001
# other       30002
# work        30002
# dtype: int64

# %%
filldf = df1.fillna(0)
filldf
# Out:
#        rownames morekids gender1 gender2   age afam hispanic other  work
# 0             1       no  female  female  35.0   no       no    no    40
# 1             2       no  female    male  33.0   no       no    no    52
# 2             3       no  female  female  28.0   no       no    no    12
# 3             4       no    male    male  28.0   no       no    no     0
# 4             5       no  female    male  31.0   no       no    no     0
# ...         ...      ...     ...     ...   ...  ...      ...   ...   ...
# 29997     29998      yes    male  female  34.0   no       no    no    42
# 29998     29999      yes    male    male  31.0  yes       no    no    52
# 29999     30000       no  female  female  29.0   no       no    no     0
# 30001     29721       no    male    male   0.0   no       no    no     6
# 30002      5577       no    male  female  33.0   no        0    no    22
#
# [30002 rows x 9 columns]

# %%
print("Mean of age(With NaN): ",df["age"].mean())
print("Mean of age(Without NaN): ",filldf["age"].mean())
# Out:
# Mean of age(With NaN):  30.354429114177165
# Mean of age(Without NaN):  30.353343110459303

# %%
mean_df = df1["age"].fillna(df1["age"].mean())
mean_df
df1["age"] = mean_df
df1
# Out:
# <ipython-input-18-fcccd9864d47>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["age"] = mean_df
#        rownames morekids gender1 gender2        age afam hispanic other  work
# 0             1       no  female  female  35.000000   no       no    no    40
# 1             2       no  female    male  33.000000   no       no    no    52
# 2             3       no  female  female  28.000000   no       no    no    12
# 3             4       no    male    male  28.000000   no       no    no     0
# 4             5       no  female    male  31.000000   no       no    no     0
# ...         ...      ...     ...     ...        ...  ...      ...   ...   ...
# 29997     29998      yes    male  female  34.000000   no       no    no    42
# ...

# %%
forward_fill = df1["age"].fillna(method='ffill')
forward_fill
# Out:
# <ipython-input-19-5bbe233f59c9>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   forward_fill = df1["age"].fillna(method='ffill')
# 0        35.000000
# 1        33.000000
# 2        28.000000
# 3        28.000000
# 4        31.000000
#            ...
# 29997    34.000000
# 29998    31.000000
# 29999    29.000000
# 30001    30.354355
# 30002    33.000000
# Name: age, Length: 30002, dtype: float64

# %%
backward_fill = df1["age"].fillna(method='bfill')
backward_fill
# Out:
# <ipython-input-20-629c87d495e7>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   backward_fill = df1["age"].fillna(method='bfill')
# 0        35.000000
# 1        33.000000
# 2        28.000000
# 3        28.000000
# 4        31.000000
#            ...
# 29997    34.000000
# 29998    31.000000
# 29999    29.000000
# 30001    30.354355
# 30002    33.000000
# Name: age, Length: 30002, dtype: float64

# %%
numerical_summary = df1.describe()  # Numerical summary
numerical_summary
# Out:
#            rownames           age          work
# count  30002.000000  30002.000000  30002.000000
# mean   15000.676555     30.354355     19.209153
# std     8660.697594      3.383353     21.940425
# min        1.000000     21.000000      0.000000
# 25%     7500.250000     28.000000      0.000000
# 50%    15000.500000     31.000000      6.000000
# 75%    22500.750000     33.000000     45.000000
# max    30000.000000     35.000000     52.000000

# %%
categorical_summary = df1.describe(include='object')
categorical_summary
# Out:
#        morekids gender1 gender2   afam hispanic  other
# count     30002   30002   30002  30002    30001  30002
# unique        2       2       2      2        2      2
# top          no    male    male     no       no     no
# freq      18674   15453   15183  28404    27769  28297

# %%
#21BDS0184
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for c in df1.columns:
    if df1[c].dtype == 'object':
        df1[c] = le.fit_transform(df1[c])
# Out:
# <ipython-input-23-e099a1f424c6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[c] = le.fit_transform(df1[c])
# <ipython-input-23-e099a1f424c6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[c] = le.fit_transform(df1[c])
# <ipython-input-23-e099a1f424c6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#21BDS0184
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Correlation matrix
correlation_matrix = df1.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
# Scatter plots for numerical variables
sns.pairplot(df1, vars=['age', 'work'], diag_kind='kde')
plt.suptitle("Scatter Plots of Numerical Variables", y=1.02)
plt.show()

# %%
# Contingency table for `morekids` and `gender1`
contingency_table = pd.crosstab(df1['morekids'], df1['gender1'])
print("\nContingency Table (morekids vs gender1):")
print(contingency_table)
# Out:
# Contingency Table (morekids vs gender1):
# gender1      0     1
# morekids
# 0         9026  9648
# 1         5523  5805

# %%
# Heatmap of the contingency table
plt.figure(figsize=(6, 4))
sns.heatmap(contingency_table, annot=True, cmap="YlGnBu", cbar=False, fmt="d")
plt.title("Heatmap of Categorical Variables")
plt.show()

# %%
# Box plot of `age` by `morekids`
plt.figure(figsize=(8, 6))
sns.boxplot(x='morekids', y='age', data=df1)
plt.title("Box Plot of Age by Morekids")
plt.show()

# %%
# Box plot of `work` by `gender1`
plt.figure(figsize=(8, 6))
sns.boxplot(x='gender1', y='work', data=df1)
plt.title("Box Plot of Work Hours by Gender1")
plt.show()

# %%
# Group statistics (numerical grouped by categorical)
grouped_stats_age = df1.groupby('morekids')['age'].describe()
print("\nGrouped Statistics (Age by Morekids):")
print(grouped_stats_age)
# Out:
# Grouped Statistics (Age by Morekids):
#             count       mean       std   min   25%   50%   75%   max
# morekids
# 0         18674.0  30.068349  3.443968  21.0  28.0  31.0  33.0  35.0
# 1         11328.0  30.825830  3.226252  21.0  29.0  31.0  33.0  35.0

# %%
# Violin Plot (Age by Gender1 and Morekids)
plt.figure(figsize=(12, 6))
sns.violinplot(x='gender1', y='age', hue='morekids', data=df1, split=True, palette="muted")
plt.title("Age Distribution by Gender1 and Morekids")
plt.show()

# %%
#21BDS0184
# Fixed Binning for Age
bins_age = [20, 25, 30, 35]  # Define age intervals
labels_age = ['20-25', '25-30', '30-35']  # Labels for age bins
df1['age_bins_fixed'] = pd.cut(df1['age'], bins=bins_age, labels=labels_age, include_lowest=True)
print("\nData with Fixed Age Bins:")
print(df1[['age', 'age_bins_fixed']])
# Out:
# Data with Fixed Age Bins:
#              age age_bins_fixed
# 0      35.000000          30-35
# 1      33.000000          30-35
# 2      28.000000          25-30
# 3      28.000000          25-30
# 4      31.000000          30-35
# ...          ...            ...
# 29997  34.000000          30-35
# 29998  31.000000          30-35
# 29999  29.000000          25-30
# 30001  30.354355          30-35
# 30002  33.000000          30-35
#
# [30002 rows x 2 columns]
# <ipython-input-33-7679efc3d841>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['age_bins_fixed'] = pd.cut(df1['age'], bins=bins_age, labels=labels_age, include_lowest=True)

# %%
#21BDS0184
# Quantile Binning for Age (Equal-sized bins)
df1['age_bins_quantile'] = pd.qcut(df1['age'], q=4, labels=['Q1', 'Q2', 'Q3', 'Q4'])
print("\nData with Quantile Age Bins (Equal-sized):")
print(df1[['age', 'age_bins_quantile']])
# Out:
# Data with Quantile Age Bins (Equal-sized):
#              age age_bins_quantile
# 0      35.000000                Q4
# 1      33.000000                Q3
# 2      28.000000                Q1
# 3      28.000000                Q1
# 4      31.000000                Q2
# ...          ...               ...
# 29997  34.000000                Q4
# 29998  31.000000                Q2
# 29999  29.000000                Q2
# 30001  30.354355                Q2
# 30002  33.000000                Q3
#
# [30002 rows x 2 columns]
# <ipython-input-34-a86eb886f79e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['age_bins_quantile'] = pd.qcut(df1['age'], q=4, labels=['Q1', 'Q2', 'Q3', 'Q4'])

# %%
df1[df1['work'] > 40]
# Out:
#        rownames  morekids  gender1  gender2   age  afam  hispanic  other  \
# 1             2         0        0        1  33.0     0         0      0
# 14           15         0        0        0  32.0     0         0      0
# 15           16         0        0        1  35.0     0         0      0
# 16           17         0        1        1  29.0     0         0      0
# 20           21         0        0        0  33.0     0         0      0
# ...         ...       ...      ...      ...   ...   ...       ...    ...
# 29981     29982         0        0        0  32.0     0         1      1
# 29988     29989         0        1        0  27.0     0         0      0
# 29989     29990         0        1        0  28.0     0         0      0
# 29997     29998         1        1        0  34.0     0         0      0
# 29998     29999         1        1        1  31.0     1         0      0
#
#        work age_bins_fixed age_bins_quantile
# 1        52          30-35                Q3
# ...

# %%
#21BDS0184
# Scatter Plot: Age vs Work
plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='work', data=df1, hue='morekids',
                style='gender1', palette='deep')
plt.title("Scatter Plot: Age vs Work")
plt.xlabel("Age")
plt.ylabel("Work Hours")
plt.legend(title="Morekids & Gender1", loc='upper right')
plt.show()

# %%
# Scatter Plot: Age vs Morekids
plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='morekids', data=df1,
                hue='gender1', palette='deep')
plt.title("Scatter Plot: Age vs Morekids")
plt.xlabel("Age")
plt.ylabel("Morekids")
plt.legend(title="Gender1", loc='upper right')
plt.show()

# %%
# Dot Chart: Distribution of Work by Gender1
plt.figure(figsize=(8, 6))
sns.stripplot(x='gender1', y='work', data=df1,
              jitter=True, palette='Set3', dodge=True)
plt.title("Dot Chart: Distribution of Work by Gender1")
plt.xlabel("Gender1")
plt.ylabel("Work Hours")
plt.show()
# Out:
# <ipython-input-38-e31472b5a1d6>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='gender1', y='work', data=df1,

# %%
#21BDS0184
df1 = df1.drop(columns=['age_bins_fixed', 'age_bins_quantile'])
df1.isna().sum()
# Out:
# rownames    0
# morekids    0
# gender1     0
# gender2     0
# age         0
# afam        0
# hispanic    0
# other       0
# work        0
# dtype: int64

# %%
# Preprocessing the Data (Standardization)
# Select relevant features for clustering
from sklearn.preprocessing import StandardScaler

features = df1[['age', 'work', 'morekids']]
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# %%
#21BDS0184
from sklearn.cluster import KMeans

# Apply K-means Clustering
# Choose the number of clusters (k), for example, k=3
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(features_scaled)

# Add the cluster labels to the original data
df1['Cluster'] = clusters

# Visualize Clusters
# Scatter Plot: Age vs Work colored by Cluster
plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='work', hue='Cluster', data=df1,
                palette='Set2', s=100, marker='o')
plt.title("K-means Clustering: Age vs Work")
plt.xlabel("Age")
plt.ylabel("Work Hours")
plt.legend(title="Cluster")
plt.show()

# %%
# Pair Plot: Visualize clusters for multiple features
sns.pairplot(df1[['age', 'work', 'morekids', 'Cluster']],
             hue='Cluster', palette='Set2')
plt.suptitle("Pair Plot of Clusters", y=1.02)
plt.show()

# %%
# Elbow Method to Determine the Optimal Number of Clusters
# This step helps identify the best 'k' value for K-means
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(features_scaled)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), inertia, marker='o', color='b')
plt.title("Elbow Method for Optimal Number of Clusters")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.show()

# %%
#21BDS0184
from sklearn.decomposition import PCA

# Apply PCA
pca = PCA(n_components=2)  # Reduce to 2 dimensions for visualization
pca_components = pca.fit_transform(features_scaled)

# Create a DataFrame for the principal components
pca_df = pd.DataFrame(data=pca_components, columns=['PC1', 'PC2'])

# Add the cluster or any other labels to the DataFrame for coloring the plot (optional)
pca_df['Cluster'] = df1['Cluster']  # If you have clusters or use 'morekids' or 'gender1'

# Visualize the PCA components (Scatter Plot)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', hue='Cluster', data=pca_df, palette='Set2', s=100)
plt.title("PCA: First and Second Principal Components")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend(title="Cluster")
plt.show()

# %%
# Explained Variance
print(f"Explained variance ratio of the components: {pca.explained_variance_ratio_}")
print(f"Total explained variance: {np.sum(pca.explained_variance_ratio_)}")
# Out:
# Explained variance ratio of the components: [0.37758084 0.36708852]
# Total explained variance: 0.7446693553508583

# %%
# Scree Plot: Visualize the explained variance for each component
plt.figure(figsize=(8, 6))
sns.barplot(x=[f'PC{i+1}' for i in range(len(pca.explained_variance_ratio_))],
            y=pca.explained_variance_ratio_)
plt.title("Scree Plot: Explained Variance by Principal Component")
plt.xlabel("Principal Components")
plt.ylabel("Explained Variance Ratio")
plt.show()

# %%
#21BDS0184
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# Apply Agglomerative Clustering
# Number of clusters, e.g., 3 (you can experiment with this)
hac = AgglomerativeClustering(n_clusters=3)
df1['HAC_Cluster'] = hac.fit_predict(features_scaled)

# Visualize the Dendrogram (Hierarchical Clustering Tree)
# Perform the linkage for hierarchical clustering (ward method minimizes variance)
linked = linkage(features_scaled, method='ward')

# %%
#21BDS0184
# Plot the dendrogram
plt.figure(figsize=(10, 7))
dendrogram(linked)
plt.title('Hierarchical Clustering Dendrogram (Ward Linkage)')
plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.show()

# %%
# Visualize the HAC Clusters (Scatter plot example)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='work', hue='HAC_Cluster', data=df1, palette='Set2', s=100)
plt.title("Agglomerative Clustering: Age vs Work")
plt.xlabel("Age")
plt.ylabel("Work Hours")
plt.legend(title="HAC Cluster")
plt.show()

# %%
# Evaluate the clustering (Optional)
# You can check cluster sizes to understand the distribution
cluster_sizes = df1['HAC_Cluster'].value_counts()
print(f"Cluster Sizes: \n{cluster_sizes}")
# Out:
# Cluster Sizes:
# HAC_Cluster
# 0    11328
# 1    10796
# 2     7878
# Name: count, dtype: int64

# %%
#21BDS0184
from sklearn.decomposition import TruncatedSVD

# Apply Singular Value Decomposition (SVD)
svd = TruncatedSVD(n_components=2)  # Reduce to 2 components for visualization
svd_components = svd.fit_transform(features_scaled)

# Create a DataFrame for the SVD components
svd_df = pd.DataFrame(data=svd_components, columns=['SVD1', 'SVD2'])

# %%
# Visualize the SVD components (Scatter Plot)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='SVD1', y='SVD2', data=svd_df, hue=df1['morekids'], palette='Set2', s=100)
plt.title("SVD: First and Second Components")
plt.xlabel("Singular Value Decomposition 1")
plt.ylabel("Singular Value Decomposition 2")
plt.legend(title="Morekids")
plt.show()

# %%
# Plot the Singular Values
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(svd.singular_values_) + 1), svd.singular_values_, marker='o', color='b')
plt.title("Singular Values")
plt.xlabel("Index")
plt.ylabel("Singular Value")
plt.show()

# %%
explained_variance = svd.explained_variance_ratio_
print(f"Explained variance ratio of each component: {explained_variance}")
print(f"Total explained variance: {np.sum(explained_variance)}")
# Out:
# Explained variance ratio of each component: [0.37758084 0.36708852]
# Total explained variance: 0.7446693553509067

# %%
#21BDS0184
from sklearn.manifold import MDS

# Apply Multidimensional Scaling (MDS)
mds = MDS(n_components=2, random_state=42)  # Reduce to 2 dimensions for visualization
mds_components = mds.fit_transform(features_scaled)

# Create a DataFrame for the MDS components
mds_df = pd.DataFrame(data=mds_components, columns=['MDS1', 'MDS2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c3e38cfe7eb3> in <cell line: 6>()
#       4 # Apply Multidimensional Scaling (MDS)
#       5 mds = MDS(n_components=2, random_state=42)  # Reduce to 2 dimensions for visualization
# ----> 6 mds_components = mds.fit_transform(features_scaled)
#       7
#       8 # Create a DataFrame for the MDS components
#
# NameError: name 'features_scaled' is not defined

# %%
# Visualize the MDS components (Scatter Plot)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='MDS1', y='MDS2', hue=df1['morekids'], palette='Set2', s=100)
plt.title("MDS: First and Second Components")
plt.xlabel("MDS Component 1")
plt.ylabel("MDS Component 2")
plt.legend(title="Morekids")
plt.show()

# %%
# Plot the Stress (Goodness of fit)
# The stress value indicates how well the MDS configuration fits the original distance matrix
print(f"MDS Stress Value: {mds.stress_}")

# %%
#21BDS0184
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Select all the features and the target variable
features = data_cleaned[['morekids', 'gender1', 'gender2', 'age', 'afam', 'hispanic', 'other']]  # Features
target = data_cleaned['work']  # Target variable is 'work'

# Standardize the features (important for linear regression)
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(features_scaled, target, test_size=0.2, random_state=42)

# Build the Linear Regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Predict on the test data
y_pred = model.predict(X_test)

# %%
df1.head()

# %%
# Visualizing the predictions vs actual values
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', label='Predictions')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--', label='Perfect Fit')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values (Linear Regression)")
plt.legend()
plt.show()

# %%
#21BDS0184
# Evaluate the model
# R-squared (Coefficient of Determination)
r2 = r2_score(y_test, y_pred)

# Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Print evaluation metrics
print(f"R² (Coefficient of Determination): {r2:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
